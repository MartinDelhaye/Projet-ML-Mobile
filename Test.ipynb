# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinDelhaye/Projet-ML-Mobile/blob/dev/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# test
